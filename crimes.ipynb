# %% [markdown]
# ## <h1><center>Предобработка данных по преступлениям и обьединение в одну базу данных</center></h1>
# ![alt text](Диаграммы/1681275794_kartinki-pibig-info-p-kartinki-ubiistvo-dlya-prezentatsii-arti-15.jpg)

# %%
import pandas as pd
import numpy as np

# %%
egs_4116 = pd.read_excel('crimes/4-EGS_Razdel_4_012016.xls', header=9)
egs_4116 = egs_4116.drop('Unnamed: 0', axis=1)
column_name = {'Unnamed: 1': 'Регион', 'несовершеннолетними или при их соучастии\n': 'Несовершеннолетними или при их соучастии',
               'ранее совершавшими преступления\n': 'Ранее совершавшими преступления', 'в том числе': 'В том числе ранее судимыми', 
               'группой лиц\n': 'Группой лиц', 'группой лиц по предварительному сговору\n': 'Группой лиц по предварительному сговору',
               'организованной группой\n':'Организованной группой', 'преступным сообществом (преступной организацией)\n':'Преступным сообществом (преступной организацией)',
               'в состоянии опьянения': 'В состоянии алкогольного опьянения', 'Unnamed: 10': 'В состоянии наркотического опьянения',
               'Unnamed: 11': 'В состоянии токсического опьянения'}
egs_4116 = egs_4116.rename(columns=column_name)
egs_4116 = egs_4116.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4116
# Out:
#                               Регион  \
# 0               Российская Федерация
# 1      Центральный федеральный округ
# 2               Белгородская область
# 3                   Брянская область
# 4               Владимирская область
# ..                               ...
# 100          УТ МВД по Сибирскому ФО
# 101    УТ МВД по Северо-Западному ФО
# 102    УТ МВД по Дальневосточному ФО
# 103  УТ МВД по Северо-Кавказскому ФО
# 104           УТ МВД по Крымскому ФО
#
#      Несовершеннолетними или при их соучастии  \
# 0                                      3778.0
# 1                                       533.0
# 2                                        14.0
# 3                                        27.0
# 4                                        44.0
# ..                                        ...
# 100                                       1.0
# 101                                       0.0
# 102                                       7.0
# ...

# %%
list_region = ['Транспорт России', 'УТ МВД по Южному ФО', 'Крымский федеральный округ','УТ МВД по Уральскому ФО', 'УТ МВД по Центральному ФО',
       'УТ МВД по Приволжскому ФО', 'УТ МВД по Сибирскому ФО', 'УТ МВД по Северо-Западному ФО', 'УТ МВД по Дальневосточному ФО',
       'УТ МВД по Северо-Кавказскому ФО', 'УТ МВД по Крымскому ФО', 'Дальневосточный федеральный округ', 'Сибирский федеральный округ',
       'Уральский федеральный округ', 'Приволжский федеральный округ', 'Южный федеральный округ', 'Северо-Кавказский федеральный округ',
       'Северо-Западный федеральный округ', 'Российская Федерация', 'Центральный федеральный округ']
egs_4116 = egs_4116[~egs_4116['Регион'].isin(list_region)]
egs_4116['Регион'] = egs_4116['Регион'].str.replace(r"\(.*\)","")
egs_4116 = egs_4116.reset_index(drop=True)
egs_4116.loc[:, egs_4116.columns != 'Регион'] = egs_4116.loc[:, egs_4116.columns != 'Регион'].astype(int)
egs_4116.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1327561050.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4116['Регион'] = egs_4116['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1327561050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   egs_4116['Регион'] = egs_4116['Регион'].str.replace(r"\(.*\)","")
# ...

# %%
egs_4116
# Out:
#                         Регион  Несовершеннолетними или при их соучастии  \
# 0         Белгородская область                                        14
# 1             Брянская область                                        27
# 2         Владимирская область                                        44
# 3          Воронежская область                                        50
# 4           Ивановская область                                        24
# ..                         ...                                       ...
# 80         Сахалинская область                                        21
# 81            Хабаровский край                                        88
# 82  Чукотский автономный округ                                         0
# 83              г. Севастополь                                         4
# 84             Республика Крым                                        49
#
#     Ранее совершавшими преступления  В том числе ранее судимыми  Группой лиц  \
# ...

# %%
egs_4216 = pd.read_excel('crimes/4-EGS_Razdel_4_022016.xls', header=9)
egs_4216 = egs_4216.drop('Unnamed: 0', axis=1)
egs_4216 = egs_4216.rename(columns=column_name)
egs_4216 = egs_4216.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4216 = egs_4216[~egs_4216['Регион'].isin(list_region)]
egs_4216['Регион'] = egs_4216['Регион'].str.replace(r"\(.*\)","")
egs_4216 = egs_4216.reset_index(drop=True)
egs_4216.loc[:, egs_4216.columns != 'Регион'] = egs_4216.loc[:, egs_4216.columns != 'Регион'].astype(int)
egs_4216.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3839924554.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4216['Регион'] = egs_4216['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3839924554.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4216.loc[:, egs_4216.columns != 'Регион'] = egs_4216.loc[:, egs_4216.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4216
# Out:
#                         Регион  Несовершеннолетними или при их соучастии  \
# 0         Белгородская область                                        30
# 1             Брянская область                                        57
# 2         Владимирская область                                        86
# 3          Воронежская область                                        90
# 4           Ивановская область                                        42
# ..                         ...                                       ...
# 80         Сахалинская область                                        40
# 81            Хабаровский край                                       171
# 82  Чукотский автономный округ                                         2
# 83              г. Севастополь                                        12
# 84             Республика Крым                                        86
#
#     Ранее совершавшими преступления  В том числе ранее судимыми  Группой лиц  \
# ...

# %%
egs_4316 = pd.read_excel('crimes/4-EGS_Razdel_4_032016.xls', header=9)
egs_4316 = egs_4316.drop('Unnamed: 0', axis=1)
egs_4316 = egs_4316.rename(columns=column_name)
egs_4316 = egs_4316.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4316 = egs_4316[~egs_4316['Регион'].isin(list_region)]
egs_4316['Регион'] = egs_4316['Регион'].str.replace(r"\(.*\)","")
egs_4316 = egs_4316.reset_index(drop=True)
egs_4316.loc[:, egs_4316.columns != 'Регион'] = egs_4316.loc[:, egs_4316.columns != 'Регион'].astype(int)
egs_4316.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2867470740.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4316['Регион'] = egs_4316['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2867470740.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4316.loc[:, egs_4316.columns != 'Регион'] = egs_4316.loc[:, egs_4316.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4416 = pd.read_excel('crimes/4-EGS_Razdel_4_042016.xls', header=9)
egs_4416 = egs_4416.drop('Unnamed: 0', axis=1)
egs_4416 = egs_4416.rename(columns=column_name)
egs_4416 = egs_4416.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4416 = egs_4416[~egs_4416['Регион'].isin(list_region)]
egs_4416['Регион'] = egs_4416['Регион'].str.replace(r"\(.*\)","")
egs_4416 = egs_4416.reset_index(drop=True)
egs_4416.loc[:, egs_4416.columns != 'Регион'] = egs_4416.loc[:, egs_4416.columns != 'Регион'].astype(int)
egs_4416.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1623954567.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4416['Регион'] = egs_4416['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1623954567.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4416.loc[:, egs_4416.columns != 'Регион'] = egs_4416.loc[:, egs_4416.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4516 = pd.read_excel('crimes/4-EGS_Razdel_4_052016.xls', header=9)
egs_4516 = egs_4516.drop('Unnamed: 0', axis=1)
egs_4516 = egs_4516.rename(columns=column_name)
egs_4516 = egs_4516.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4516 = egs_4516[~egs_4516['Регион'].isin(list_region)]
egs_4516['Регион'] = egs_4516['Регион'].str.replace(r"\(.*\)","")
egs_4516 = egs_4516.reset_index(drop=True)
egs_4516.loc[:, egs_4516.columns != 'Регион'] = egs_4516.loc[:, egs_4516.columns != 'Регион'].astype(int)
egs_4516.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1610127806.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4516['Регион'] = egs_4516['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1610127806.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4516.loc[:, egs_4516.columns != 'Регион'] = egs_4516.loc[:, egs_4516.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4616 = pd.read_excel('crimes/4-EGS_Razdel_4_062016.xls', header=9)
egs_4616 = egs_4616.drop('Unnamed: 0', axis=1)
egs_4616 = egs_4616.rename(columns=column_name)
egs_4616 = egs_4616.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4616 = egs_4616[~egs_4616['Регион'].isin(list_region)]
egs_4616['Регион'] = egs_4616['Регион'].str.replace(r"\(.*\)","")
egs_4616 = egs_4616.reset_index(drop=True)
egs_4616.loc[:, egs_4616.columns != 'Регион'] = egs_4616.loc[:, egs_4616.columns != 'Регион'].astype(int)
egs_4616.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\737484329.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4616['Регион'] = egs_4616['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\737484329.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4616.loc[:, egs_4616.columns != 'Регион'] = egs_4616.loc[:, egs_4616.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4716 = pd.read_excel('crimes/4-EGS_Razdel_4_072016.xls', header=9)
egs_4716 = egs_4716.drop('Unnamed: 0', axis=1)
egs_4716 = egs_4716.rename(columns=column_name)
egs_4716 = egs_4716.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4716 = egs_4716[~egs_4716['Регион'].isin(list_region)]
egs_4716['Регион'] = egs_4716['Регион'].str.replace(r"\(.*\)","")
egs_4716 = egs_4716.reset_index(drop=True)
egs_4716.loc[:, egs_4716.columns != 'Регион'] = egs_4716.loc[:, egs_4716.columns != 'Регион'].astype(int)
egs_4716.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1269805936.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4716['Регион'] = egs_4716['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1269805936.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4716.loc[:, egs_4716.columns != 'Регион'] = egs_4716.loc[:, egs_4716.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4816 = pd.read_excel('crimes/4-EGS_Razdel_4_082016.xls', header=9)
egs_4816 = egs_4816.drop('Unnamed: 0', axis=1)
egs_4816 = egs_4816.rename(columns=column_name)
egs_4816 = egs_4816.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4816 = egs_4816[~egs_4816['Регион'].isin(list_region)]
egs_4816['Регион'] = egs_4816['Регион'].str.replace(r"\(.*\)","")
egs_4816 = egs_4816.reset_index(drop=True)
egs_4816.loc[:, egs_4816.columns != 'Регион'] = egs_4816.loc[:, egs_4816.columns != 'Регион'].astype(int)
egs_4816.Регион.unique()
# Out:
# WARNING *** file size (120785) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3137252154.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4816['Регион'] = egs_4816['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3137252154.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4816.loc[:, egs_4816.columns != 'Регион'] = egs_4816.loc[:, egs_4816.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4916 = pd.read_excel('crimes/4-EGS_Razdel_4_092016.xls', header=9)
egs_4916 = egs_4916.drop('Unnamed: 0', axis=1)
egs_4916 = egs_4916.rename(columns=column_name)
egs_4916 = egs_4916.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4916 = egs_4916[~egs_4916['Регион'].isin(list_region)]
egs_4916['Регион'] = egs_4916['Регион'].str.replace(r"\(.*\)","")
egs_4916 = egs_4916.reset_index(drop=True)
egs_4916.loc[:, egs_4916.columns != 'Регион'] = egs_4916.loc[:, egs_4916.columns != 'Регион'].astype(int)
egs_4916.Регион.unique()
# Out:
# WARNING *** file size (120789) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\458667816.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4916['Регион'] = egs_4916['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\458667816.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4916.loc[:, egs_4916.columns != 'Регион'] = egs_4916.loc[:, egs_4916.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41016 = pd.read_excel('crimes/4-EGS_Razdel_4_102016.xls', header=9)
egs_41016 = egs_41016.drop('Unnamed: 0', axis=1)
egs_41016 = egs_41016.rename(columns=column_name)
egs_41016 = egs_41016.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41016 = egs_41016[~egs_41016['Регион'].isin(list_region)]
egs_41016['Регион'] = egs_41016['Регион'].str.replace(r"\(.*\)","")
egs_41016 = egs_41016.reset_index(drop=True)
egs_41016.loc[:, egs_41016.columns != 'Регион'] = egs_41016.loc[:, egs_41016.columns != 'Регион'].astype(int)
egs_41016.Регион.unique()
# Out:
# WARNING *** file size (120787) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1947474996.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41016['Регион'] = egs_41016['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1947474996.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41016.loc[:, egs_41016.columns != 'Регион'] = egs_41016.loc[:, egs_41016.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41116 = pd.read_excel('crimes/4-EGS_Razdel_4_112016.xls', header=9)
egs_41116 = egs_41116.drop('Unnamed: 0', axis=1)
egs_41116 = egs_41116.rename(columns=column_name)
egs_41116 = egs_41116.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41116 = egs_41116[~egs_41116['Регион'].isin(list_region)]
egs_41116['Регион'] = egs_41116['Регион'].str.replace(r"\(.*\)","")
egs_41116 = egs_41116.reset_index(drop=True)
egs_41116.loc[:, egs_41116.columns != 'Регион'] = egs_41116.loc[:, egs_41116.columns != 'Регион'].astype(int)
egs_41116.Регион.unique()
# Out:
# WARNING *** file size (120785) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\129540220.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41116['Регион'] = egs_41116['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\129540220.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41116.loc[:, egs_41116.columns != 'Регион'] = egs_41116.loc[:, egs_41116.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41216 = pd.read_excel('crimes/4-EGS_Razdel_4_122016.xls', header=9)
egs_41216 = egs_41216.drop('Unnamed: 0', axis=1)
egs_41216 = egs_41216.rename(columns=column_name)
egs_41216 = egs_41216.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41216 = egs_41216[~egs_41216['Регион'].isin(list_region)]
egs_41216['Регион'] = egs_41216['Регион'].str.replace(r"\(.*\)","")
egs_41216 = egs_41216.reset_index(drop=True)
egs_41216.loc[:, egs_41216.columns != 'Регион'] = egs_41216.loc[:, egs_41216.columns != 'Регион'].astype(int)
egs_41216.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2003882879.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41216['Регион'] = egs_41216['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2003882879.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41216.loc[:, egs_41216.columns != 'Регион'] = egs_41216.loc[:, egs_41216.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_416 = pd.concat([egs_4116, egs_4216, egs_4316, egs_4416, egs_4516, egs_4616, egs_4716, egs_4816, egs_4916,
                          egs_41016, egs_41116, egs_41216]).groupby('Регион').sum().reset_index()
column_name1 = {'Несовершеннолетними или при их соучастии':'Несовершеннолетними или при их соучастии 2016',
               'Ранее совершавшими преступления':'Ранее совершавшими преступления 2016','В том числе ранее судимыми': 'В том числе ранее судимыми 2016', 
               'Группой лиц': 'Группой лиц 2016', 'Группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2016',
               'Организованной группой': 'Организованной группой 2016', 'Преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2016',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2016', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2016',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2016'}
dict_name = {'Кемеровская область':'Кемеровская область – Кузбасс', 'Республика Северная Осетия-Алания': 'Республика Северная Осетия – Алания',
              'Ханты-Мансийский автономный округ –  Югра': 'Ханты-Мансийский автономный округ – Югра'}
egs_416.Регион = egs_416.Регион.replace(dict_name, regex=True)
egs_416 = egs_416.rename(columns=column_name1)
egs_416.isna().sum().sum()
# Out:
# 0

# %%
egs_416
# Out:
#                              Регион  \
# 0                    Алтайский край
# 1                  Амурская область
# 2             Архангельская область
# 3              Астраханская область
# 4              Белгородская область
# ..                              ...
# 80  Ямало-Ненецкий автономный округ
# 81              Ярославская область
# 82                        г. Москва
# 83               г. Санкт-Петербург
# 84                   г. Севастополь
#
#     Несовершеннолетними или при их соучастии 2016  \
# 0                                            8406
# 1                                            4758
# 2                                            4589
# 3                                            2445
# 4                                            1712
# ..                                            ...
# 80                                           1580
# 81                                           3106
# 82                                           4931
# ...

# %%
egs_4117 = pd.read_excel('crimes/4-EGS_Razdel_4_012017.xls', header=9)
egs_4117 = egs_4117.drop('Unnamed: 0', axis=1)
egs_4117 = egs_4117.rename(columns=column_name)
egs_4117 = egs_4117.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4117 = egs_4117[~egs_4117['Регион'].isin(list_region)]
egs_4117['Регион'] = egs_4117['Регион'].str.replace(r"\(.*\)","")
egs_4117 = egs_4117.reset_index(drop=True)
egs_4117.loc[:, egs_4117.columns != 'Регион'] = egs_4117.loc[:, egs_4117.columns != 'Регион'].astype(int)
egs_4117.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2509972778.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4117['Регион'] = egs_4117['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2509972778.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4117.loc[:, egs_4117.columns != 'Регион'] = egs_4117.loc[:, egs_4117.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4217 = pd.read_excel('crimes/4-EGS_Razdel_4_022017.xls', header=9)
egs_4217 = egs_4217.drop('Unnamed: 0', axis=1)
egs_4217 = egs_4217.rename(columns=column_name)
egs_4217 = egs_4217.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4217 = egs_4217[~egs_4217['Регион'].isin(list_region)]
egs_4217['Регион'] = egs_4217['Регион'].str.replace(r"\(.*\)","")
egs_4217 = egs_4217.reset_index(drop=True)
egs_4217.loc[:, egs_4217.columns != 'Регион'] = egs_4217.loc[:, egs_4217.columns != 'Регион'].astype(int)
egs_4217.Регион.unique()
# Out:
# WARNING *** file size (122053) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4143902039.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4217['Регион'] = egs_4217['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4143902039.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4217.loc[:, egs_4217.columns != 'Регион'] = egs_4217.loc[:, egs_4217.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4317 = pd.read_excel('crimes/4-EGS_Razdel_4_032017.xls', header=9)
egs_4317 = egs_4317.drop('Unnamed: 0', axis=1)
egs_4317 = egs_4317.rename(columns=column_name)
egs_4317 = egs_4317.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4317 = egs_4317[~egs_4317['Регион'].isin(list_region)]
egs_4317['Регион'] = egs_4317['Регион'].str.replace(r"\(.*\)","")
egs_4317 = egs_4317.reset_index(drop=True)
egs_4317.loc[:, egs_4317.columns != 'Регион'] = egs_4317.loc[:, egs_4317.columns != 'Регион'].astype(int)
egs_4317.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3807996638.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4317['Регион'] = egs_4317['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3807996638.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4317.loc[:, egs_4317.columns != 'Регион'] = egs_4317.loc[:, egs_4317.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4417 = pd.read_excel('crimes/4-EGS_Razdel_4_042017.xls', header=9)
egs_4417 = egs_4417.drop('Unnamed: 0', axis=1)
egs_4417 = egs_4417.rename(columns=column_name)
egs_4417 = egs_4417.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4417 = egs_4417[~egs_4417['Регион'].isin(list_region)]
egs_4417['Регион'] = egs_4417['Регион'].str.replace(r"\(.*\)","")
egs_4417 = egs_4417.reset_index(drop=True)
egs_4417.loc[:, egs_4417.columns != 'Регион'] = egs_4417.loc[:, egs_4417.columns != 'Регион'].astype(int)
egs_4417.Регион.unique()
# Out:
# WARNING *** file size (122051) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4137186198.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4417['Регион'] = egs_4417['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4137186198.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4417.loc[:, egs_4417.columns != 'Регион'] = egs_4417.loc[:, egs_4417.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4517 = pd.read_excel('crimes/4-EGS_Razdel_4_052017.xls', header=9)
egs_4517 = egs_4517.drop('Unnamed: 0', axis=1)
egs_4517 = egs_4517.rename(columns=column_name)
egs_4517 = egs_4517.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4517 = egs_4517[~egs_4517['Регион'].isin(list_region)]
egs_4517['Регион'] = egs_4517['Регион'].str.replace(r"\(.*\)","")
egs_4517 = egs_4517.reset_index(drop=True)
egs_4517.loc[:, egs_4517.columns != 'Регион'] = egs_4517.loc[:, egs_4517.columns != 'Регион'].astype(int)
egs_4517.Регион.unique()
# Out:
# WARNING *** file size (122045) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2395216131.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4517['Регион'] = egs_4517['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2395216131.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4517.loc[:, egs_4517.columns != 'Регион'] = egs_4517.loc[:, egs_4517.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4617 = pd.read_excel('crimes/4-EGS_Razdel_4_062017.xls', header=9)
egs_4617 = egs_4617.drop('Unnamed: 0', axis=1)
egs_4617 = egs_4617.rename(columns=column_name)
egs_4617 = egs_4617.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4617 = egs_4617[~egs_4617['Регион'].isin(list_region)]
egs_4617['Регион'] = egs_4617['Регион'].str.replace(r"\(.*\)","")
egs_4617 = egs_4617.reset_index(drop=True)
egs_4617.loc[:, egs_4617.columns != 'Регион'] = egs_4617.loc[:, egs_4617.columns != 'Регион'].astype(int)
egs_4617.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\862167438.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4617['Регион'] = egs_4617['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\862167438.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4617.loc[:, egs_4617.columns != 'Регион'] = egs_4617.loc[:, egs_4617.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4717 = pd.read_excel('crimes/4-EGS_Razdel_4_072017.xls', header=9)
egs_4717 = egs_4717.drop('Unnamed: 0', axis=1)
egs_4717 = egs_4717.rename(columns=column_name)
egs_4717 = egs_4717.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4717 = egs_4717[~egs_4717['Регион'].isin(list_region)]
egs_4717['Регион'] = egs_4717['Регион'].str.replace(r"\(.*\)","")
egs_4717 = egs_4717.reset_index(drop=True)
egs_4717.loc[:, egs_4717.columns != 'Регион'] = egs_4717.loc[:, egs_4717.columns != 'Регион'].astype(int)
egs_4717.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3500092260.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4717['Регион'] = egs_4717['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3500092260.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4717.loc[:, egs_4717.columns != 'Регион'] = egs_4717.loc[:, egs_4717.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4817 = pd.read_excel('crimes/4-EGS_Razdel_4_082017.xls', header=9)
egs_4817 = egs_4817.drop('Unnamed: 0', axis=1)
egs_4817 = egs_4817.rename(columns=column_name)
egs_4817 = egs_4817.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4817 = egs_4817[~egs_4817['Регион'].isin(list_region)]
egs_4817['Регион'] = egs_4817['Регион'].str.replace(r"\(.*\)","")
egs_4817 = egs_4817.reset_index(drop=True)
egs_4817.loc[:, egs_4817.columns != 'Регион'] = egs_4817.loc[:, egs_4817.columns != 'Регион'].astype(int)
egs_4817.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3511673836.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4817['Регион'] = egs_4817['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3511673836.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4817.loc[:, egs_4817.columns != 'Регион'] = egs_4817.loc[:, egs_4817.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4917 = pd.read_excel('crimes/4-EGS_Razdel_4_092017.xls', header=9)
egs_4917 = egs_4917.drop('Unnamed: 0', axis=1)
egs_4917 = egs_4917.rename(columns=column_name)
egs_4917 = egs_4917.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4917 = egs_4917[~egs_4917['Регион'].isin(list_region)]
egs_4917['Регион'] = egs_4917['Регион'].str.replace(r"\(.*\)","")
egs_4917 = egs_4917.reset_index(drop=True)
egs_4917.loc[:, egs_4917.columns != 'Регион'] = egs_4917.loc[:, egs_4917.columns != 'Регион'].astype(int)
egs_4917.Регион.unique()
# Out:
# WARNING *** file size (122055) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4179726625.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4917['Регион'] = egs_4917['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4179726625.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4917.loc[:, egs_4917.columns != 'Регион'] = egs_4917.loc[:, egs_4917.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41017 = pd.read_excel('crimes/4-EGS_Razdel_4_102017.xls', header=9)
egs_41017 = egs_41017.drop('Unnamed: 0', axis=1)
egs_41017 = egs_41017.rename(columns=column_name)
egs_41017 = egs_41017.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41017 = egs_41017[~egs_41017['Регион'].isin(list_region)]
egs_41017['Регион'] = egs_41017['Регион'].str.replace(r"\(.*\)","")
egs_41017 = egs_41017.reset_index(drop=True)
egs_41017.loc[:, egs_41017.columns != 'Регион'] = egs_41017.loc[:, egs_41017.columns != 'Регион'].astype(int)
egs_41017.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\321458937.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41017['Регион'] = egs_41017['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\321458937.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41017.loc[:, egs_41017.columns != 'Регион'] = egs_41017.loc[:, egs_41017.columns != 'Регион'].astype(int)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41117 = pd.read_excel('crimes/4-EGS_Razdel_4_112017.xls', header=9)
egs_41117 = egs_41117.drop('Unnamed: 0', axis=1)
egs_41117 = egs_41117.rename(columns=column_name)
egs_41117 = egs_41117.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41117 = egs_41117[~egs_41117['Регион'].isin(list_region)]
egs_41117['Регион'] = egs_41117['Регион'].str.replace(r"\(.*\)","")
egs_41117 = egs_41117.reset_index(drop=True)
egs_41117.loc[:, egs_41117.columns != 'Регион'] = egs_41117.loc[:, egs_41117.columns != 'Регион'].astype(int)
egs_41117.Регион.unique()
# Out:
# WARNING *** file size (122051) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1196882034.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41117['Регион'] = egs_41117['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1196882034.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41117.loc[:, egs_41117.columns != 'Регион'] = egs_41117.loc[:, egs_41117.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41217 = pd.read_excel('crimes/4-EGS_Razdel_4_122017.xls', header=9)
egs_41217 = egs_41217.drop('Unnamed: 0', axis=1)
egs_41217 = egs_41217.rename(columns=column_name)
egs_41217 = egs_41217.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41217 = egs_41217[~egs_41217['Регион'].isin(list_region)]
egs_41217['Регион'] = egs_41217['Регион'].str.replace(r"\(.*\)","")
egs_41217 = egs_41217.reset_index(drop=True)
egs_41217.loc[:, egs_41217.columns != 'Регион'] = egs_41217.loc[:, egs_41217.columns != 'Регион'].astype(int)
egs_41217.Регион.unique()
# Out:
# WARNING *** file size (122053) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3003023862.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41217['Регион'] = egs_41217['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3003023862.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41217.loc[:, egs_41217.columns != 'Регион'] = egs_41217.loc[:, egs_41217.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_417 = pd.concat([egs_4117, egs_4217, egs_4317, egs_4417, egs_4517, egs_4617, egs_4717, egs_4817, egs_4917,
                          egs_41017, egs_41117, egs_41217]).groupby('Регион').sum().reset_index()
column_name1 = {'Несовершеннолетними или при их соучастии':'Несовершеннолетними или при их соучастии 2017',
               'Ранее совершавшими преступления':'Ранее совершавшими преступления 2017','В том числе ранее судимыми': 'В том числе ранее судимыми 2017', 
               'Группой лиц': 'Группой лиц 2017', 'Группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2017',
               'Организованной группой': 'Организованной группой 2017', 'Преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2017',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2017', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2017',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2017'}
egs_417.Регион = egs_417.Регион.replace(dict_name, regex=True)
egs_417 = egs_417.rename(columns=column_name1)
egs_417.isna().sum().sum()
# Out:
# 0

# %%
egs_4118 = pd.read_excel('crimes/4-EGS_Razdel_4_012018.xls', header=9)
egs_4118 = egs_4118.drop('Unnamed: 0', axis=1)
egs_4118 = egs_4118.rename(columns=column_name)
egs_4118 = egs_4118.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4118 = egs_4118[~egs_4118['Регион'].isin(list_region)]
egs_4118['Регион'] = egs_4118['Регион'].str.replace(r"\(.*\)","")
egs_4118 = egs_4118.reset_index(drop=True)
egs_4118.loc[:, egs_4118.columns != 'Регион'] = egs_4118.loc[:, egs_4118.columns != 'Регион'].astype(int)
egs_4118.Регион.unique()
# Out:
# WARNING *** file size (122033) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3200728784.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4118['Регион'] = egs_4118['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3200728784.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4118.loc[:, egs_4118.columns != 'Регион'] = egs_4118.loc[:, egs_4118.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4218 = pd.read_excel('crimes/4-EGS_Razdel_4_022018.xls', header=9)
egs_4218 = egs_4218.drop('Unnamed: 0', axis=1)
egs_4218 = egs_4218.rename(columns=column_name)
egs_4218 = egs_4218.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4218 = egs_4218[~egs_4218['Регион'].isin(list_region)]
egs_4218['Регион'] = egs_4218['Регион'].str.replace(r"\(.*\)","")
egs_4218 = egs_4218.reset_index(drop=True)
egs_4218.loc[:, egs_4218.columns != 'Регион'] = egs_4218.loc[:, egs_4218.columns != 'Регион'].astype(int)
egs_4218.Регион.unique()
# Out:
# WARNING *** file size (122053) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4174814757.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4218['Регион'] = egs_4218['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4174814757.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4218.loc[:, egs_4218.columns != 'Регион'] = egs_4218.loc[:, egs_4218.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4318 = pd.read_excel('crimes/4-EGS_Razdel_4_032018.xls', header=9)
egs_4318 = egs_4318.drop('Unnamed: 0', axis=1)
egs_4318 = egs_4318.rename(columns=column_name)
egs_4318 = egs_4318.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4318 = egs_4318[~egs_4318['Регион'].isin(list_region)]
egs_4318['Регион'] = egs_4318['Регион'].str.replace(r"\(.*\)","")
egs_4318 = egs_4318.reset_index(drop=True)
egs_4318.loc[:, egs_4318.columns != 'Регион'] = egs_4318.loc[:, egs_4318.columns != 'Регион'].astype(int)
egs_4318.Регион.unique()
# Out:
# WARNING *** file size (122047) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1382964736.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4318['Регион'] = egs_4318['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1382964736.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4318.loc[:, egs_4318.columns != 'Регион'] = egs_4318.loc[:, egs_4318.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4418 = pd.read_excel('crimes/4-EGS_Razdel_4_042018.xls', header=9)
egs_4418 = egs_4418.drop('Unnamed: 0', axis=1)
egs_4418 = egs_4418.rename(columns=column_name)
egs_4418 = egs_4418.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4418 = egs_4418[~egs_4418['Регион'].isin(list_region)]
egs_4418['Регион'] = egs_4418['Регион'].str.replace(r"\(.*\)","")
egs_4418 = egs_4418.reset_index(drop=True)
egs_4418.loc[:, egs_4418.columns != 'Регион'] = egs_4418.loc[:, egs_4418.columns != 'Регион'].astype(int)
egs_4418.Регион.unique()
# Out:
# WARNING *** file size (122051) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3120316080.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4418['Регион'] = egs_4418['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3120316080.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4418.loc[:, egs_4418.columns != 'Регион'] = egs_4418.loc[:, egs_4418.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4518 = pd.read_excel('crimes/4-EGS_Razdel_4_052018.xls', header=9)
egs_4518 = egs_4518.drop('Unnamed: 0', axis=1)
egs_4518 = egs_4518.rename(columns=column_name)
egs_4518 = egs_4518.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4518 = egs_4518[~egs_4518['Регион'].isin(list_region)]
egs_4518['Регион'] = egs_4518['Регион'].str.replace(r"\(.*\)","")
egs_4518 = egs_4518.reset_index(drop=True)
egs_4518.loc[:, egs_4518.columns != 'Регион'] = egs_4518.loc[:, egs_4518.columns != 'Регион'].astype(int)
egs_4518.Регион.unique()
# Out:
# WARNING *** file size (122045) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3822544598.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4518['Регион'] = egs_4518['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3822544598.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4518.loc[:, egs_4518.columns != 'Регион'] = egs_4518.loc[:, egs_4518.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4618 = pd.read_excel('crimes/4-EGS_Razdel_4_062018.xls', header=9)
egs_4618 = egs_4618.drop('Unnamed: 0', axis=1)
egs_4618 = egs_4618.rename(columns=column_name)
egs_4618 = egs_4618.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4618 = egs_4618[~egs_4618['Регион'].isin(list_region)]
egs_4618['Регион'] = egs_4618['Регион'].str.replace(r"\(.*\)","")
egs_4618 = egs_4618.reset_index(drop=True)
egs_4618.loc[:, egs_4618.columns != 'Регион'] = egs_4618.loc[:, egs_4618.columns != 'Регион'].astype(int)
egs_4618.Регион.unique()
# Out:
# WARNING *** file size (122047) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\868888094.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4618['Регион'] = egs_4618['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\868888094.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4618.loc[:, egs_4618.columns != 'Регион'] = egs_4618.loc[:, egs_4618.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_4718 = pd.read_excel('crimes/4-EGS_Razdel_4_072018.xls', header=9)
egs_4718 = egs_4718.drop('Unnamed: 0', axis=1)
egs_4718 = egs_4718.rename(columns=column_name)
egs_4718 = egs_4718.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4718 = egs_4718[~egs_4718['Регион'].isin(list_region)]
egs_4718['Регион'] = egs_4718['Регион'].str.replace(r"\(.*\)","")
egs_4718 = egs_4718.reset_index(drop=True)
egs_4718.loc[:, egs_4718.columns != 'Регион'] = egs_4718.loc[:, egs_4718.columns != 'Регион'].astype(int)
egs_4718.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2273342715.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4718['Регион'] = egs_4718['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2273342715.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4718.loc[:, egs_4718.columns != 'Регион'] = egs_4718.loc[:, egs_4718.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4818 = pd.read_excel('crimes/4-EGS_Razdel_4_082018.xls', header=9)
egs_4818 = egs_4818.drop('Unnamed: 0', axis=1)
egs_4818 = egs_4818.rename(columns=column_name)
egs_4818 = egs_4818.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4818 = egs_4818[~egs_4818['Регион'].isin(list_region)]
egs_4818['Регион'] = egs_4818['Регион'].str.replace(r"\(.*\)","")
egs_4818 = egs_4818.reset_index(drop=True)
egs_4818.loc[:, egs_4818.columns != 'Регион'] = egs_4818.loc[:, egs_4818.columns != 'Регион'].astype(int)
egs_4818.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2336791381.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4818['Регион'] = egs_4818['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2336791381.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4818.loc[:, egs_4818.columns != 'Регион'] = egs_4818.loc[:, egs_4818.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4918 = pd.read_excel('crimes/4-EGS_Razdel_4_092018.xls', header=9)
egs_4918 = egs_4918.drop('Unnamed: 0', axis=1)
egs_4918 = egs_4918.rename(columns=column_name)
egs_4918 = egs_4918.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4918 = egs_4918[~egs_4918['Регион'].isin(list_region)]
egs_4918['Регион'] = egs_4918['Регион'].str.replace(r"\(.*\)","")
egs_4918 = egs_4918.reset_index(drop=True)
egs_4918.loc[:, egs_4918.columns != 'Регион'] = egs_4918.loc[:, egs_4918.columns != 'Регион'].astype(int)
egs_4918.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4146996577.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4918['Регион'] = egs_4918['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4146996577.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4918.loc[:, egs_4918.columns != 'Регион'] = egs_4918.loc[:, egs_4918.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41018 = pd.read_excel('crimes/4-EGS_Razdel_4_102018.xls', header=9)
egs_41018 = egs_41018.drop('Unnamed: 0', axis=1)
egs_41018 = egs_41018.rename(columns=column_name)
egs_41018 = egs_41018.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41018 = egs_41018[~egs_41018['Регион'].isin(list_region)]
egs_41018['Регион'] = egs_41018['Регион'].str.replace(r"\(.*\)","")
egs_41018 = egs_41018.reset_index(drop=True)
egs_41018.loc[:, egs_41018.columns != 'Регион'] = egs_41018.loc[:, egs_41018.columns != 'Регион'].astype(int)
egs_41018.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2599498530.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41018['Регион'] = egs_41018['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2599498530.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41018.loc[:, egs_41018.columns != 'Регион'] = egs_41018.loc[:, egs_41018.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41118 = pd.read_excel('crimes/4-EGS_Razdel_4_112018.xls', header=9)
egs_41118 = egs_41118.drop('Unnamed: 0', axis=1)
egs_41118 = egs_41118.rename(columns=column_name)
egs_41118 = egs_41118.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41118 = egs_41118[~egs_41118['Регион'].isin(list_region)]
egs_41118['Регион'] = egs_41118['Регион'].str.replace(r"\(.*\)","")
egs_41118 = egs_41118.reset_index(drop=True)
egs_41118.loc[:, egs_41118.columns != 'Регион'] = egs_41118.loc[:, egs_41118.columns != 'Регион'].astype(int)
egs_41118.Регион.unique()
# Out:
# WARNING *** file size (122051) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3635149517.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41118['Регион'] = egs_41118['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3635149517.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41118.loc[:, egs_41118.columns != 'Регион'] = egs_41118.loc[:, egs_41118.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_41218 = pd.read_excel('crimes/4-EGS_Razdel_4_122018.xls', header=9)
egs_41218 = egs_41218.drop('Unnamed: 0', axis=1)
egs_41218 = egs_41218.rename(columns=column_name)
egs_41218 = egs_41218.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41218 = egs_41218[~egs_41218['Регион'].isin(list_region)]
egs_41218['Регион'] = egs_41218['Регион'].str.replace(r"\(.*\)","")
egs_41218 = egs_41218.reset_index(drop=True)
egs_41218.loc[:, egs_41218.columns != 'Регион'] = egs_41218.loc[:, egs_41218.columns != 'Регион'].astype(int)
egs_41218.Регион.unique()
# Out:
# WARNING *** file size (122053) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1523823050.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41218['Регион'] = egs_41218['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1523823050.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41218.loc[:, egs_41218.columns != 'Регион'] = egs_41218.loc[:, egs_41218.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
# ...

# %%
egs_418 = pd.concat([egs_4118, egs_4218, egs_4318, egs_4418, egs_4518, egs_4618, egs_4718, egs_4818, egs_4918,
                          egs_41018, egs_41118, egs_41218]).groupby('Регион').sum().reset_index()
column_name1 = {'Несовершеннолетними или при их соучастии':'Несовершеннолетними или при их соучастии 2018',
               'Ранее совершавшими преступления':'Ранее совершавшими преступления 2018','В том числе ранее судимыми': 'В том числе ранее судимыми 2018', 
               'Группой лиц': 'Группой лиц 2018', 'Группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2018',
               'Организованной группой': 'Организованной группой 2018', 'Преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2018',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2018', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2018',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2018'}
egs_418.Регион = egs_418.Регион.replace(dict_name, regex=True)
egs_418 = egs_418.rename(columns=column_name1)
egs_418.isna().sum().sum()
# Out:
# 0

# %%
egs_4119 = pd.read_excel('crimes/4-EGS_Razdel_4_012019.xls', header=9)
egs_4119 = egs_4119.drop('Unnamed: 0', axis=1)
egs_4119 = egs_4119.rename(columns=column_name)
egs_4119 = egs_4119.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4119 = egs_4119[~egs_4119['Регион'].isin(list_region)]
egs_4119['Регион'] = egs_4119['Регион'].str.replace(r"\(.*\)","")
egs_4119 = egs_4119.reset_index(drop=True)
egs_4119.loc[:, egs_4119.columns != 'Регион'] = egs_4119.loc[:, egs_4119.columns != 'Регион'].astype(int)
egs_4119.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3015149357.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4119['Регион'] = egs_4119['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3015149357.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4119.loc[:, egs_4119.columns != 'Регион'] = egs_4119.loc[:, egs_4119.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4219 = pd.read_excel('crimes/4-EGS_Razdel_4_022019.xls', header=9)
egs_4219 = egs_4219.drop('Unnamed: 0', axis=1)
egs_4219 = egs_4219.rename(columns=column_name)
egs_4219 = egs_4219.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4219 = egs_4219[~egs_4219['Регион'].isin(list_region)]
egs_4219['Регион'] = egs_4219['Регион'].str.replace(r"\(.*\)","")
egs_4219 = egs_4219.reset_index(drop=True)
egs_4219.loc[:, egs_4219.columns != 'Регион'] = egs_4219.loc[:, egs_4219.columns != 'Регион'].astype(int)
egs_4219.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2736112138.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4219['Регион'] = egs_4219['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2736112138.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4219.loc[:, egs_4219.columns != 'Регион'] = egs_4219.loc[:, egs_4219.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4319 = pd.read_excel('crimes/4-EGS_Razdel_4_032019.xls', header=9)
egs_4319 = egs_4319.drop('Unnamed: 0', axis=1)
egs_4319 = egs_4319.rename(columns=column_name)
egs_4319 = egs_4319.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4319 = egs_4319[~egs_4319['Регион'].isin(list_region)]
egs_4319['Регион'] = egs_4319['Регион'].str.replace(r"\(.*\)","")
egs_4319 = egs_4319.reset_index(drop=True)
egs_4319.loc[:, egs_4319.columns != 'Регион'] = egs_4319.loc[:, egs_4319.columns != 'Регион'].astype(int)
egs_4319.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1163318159.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4319['Регион'] = egs_4319['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1163318159.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4319.loc[:, egs_4319.columns != 'Регион'] = egs_4319.loc[:, egs_4319.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4419 = pd.read_excel('crimes/4-EGS_Razdel_4_042019.xls', header=9)
egs_4419 = egs_4419.drop('Unnamed: 0', axis=1)
egs_4419 = egs_4419.rename(columns=column_name)
egs_4419 = egs_4419.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4419 = egs_4419[~egs_4419['Регион'].isin(list_region)]
egs_4419['Регион'] = egs_4419['Регион'].str.replace(r"\(.*\)","")
egs_4419 = egs_4419.reset_index(drop=True)
egs_4419.loc[:, egs_4419.columns != 'Регион'] = egs_4419.loc[:, egs_4419.columns != 'Регион'].astype(int)
egs_4419.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\769231588.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4419['Регион'] = egs_4419['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\769231588.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4419.loc[:, egs_4419.columns != 'Регион'] = egs_4419.loc[:, egs_4419.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4619 = pd.read_excel('crimes/4-EGS_Razdel_4_062019.xls', header=9)
egs_4619 = egs_4619.drop('Unnamed: 0', axis=1)
egs_4619 = egs_4619.rename(columns=column_name)
egs_4619 = egs_4619.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4619 = egs_4619[~egs_4619['Регион'].isin(list_region)]
egs_4619['Регион'] = egs_4619['Регион'].str.replace(r"\(.*\)","")
egs_4619 = egs_4619.reset_index(drop=True)
egs_4619.loc[:, egs_4619.columns != 'Регион'] = egs_4619.loc[:, egs_4619.columns != 'Регион'].astype(int)
egs_4619.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1473022879.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4619['Регион'] = egs_4619['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1473022879.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4619.loc[:, egs_4619.columns != 'Регион'] = egs_4619.loc[:, egs_4619.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4519 = pd.read_excel('crimes/4-EGS_Razdel_4_052019.xls', header=9)
egs_4519 = egs_4519.drop('Unnamed: 0', axis=1)
egs_4519 = egs_4519.rename(columns=column_name)
egs_4519 = egs_4519.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4519 = egs_4519[~egs_4519['Регион'].isin(list_region)]
egs_4519['Регион'] = egs_4519['Регион'].str.replace(r"\(.*\)","")
egs_4519 = egs_4519.reset_index(drop=True)
egs_4519.loc[:, egs_4519.columns != 'Регион'] = egs_4519.loc[:, egs_4519.columns != 'Регион'].astype(int)
egs_4519.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2634705236.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4519['Регион'] = egs_4519['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2634705236.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4519.loc[:, egs_4519.columns != 'Регион'] = egs_4519.loc[:, egs_4519.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4719 = pd.read_excel('crimes/4-EGS_Razdel_4_072019.xls', header=9)
egs_4719 = egs_4719.drop('Unnamed: 0', axis=1)
egs_4719 = egs_4719.rename(columns=column_name)
egs_4719 = egs_4719.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4719 = egs_4719[~egs_4719['Регион'].isin(list_region)]
egs_4719['Регион'] = egs_4719['Регион'].str.replace(r"\(.*\)","")
egs_4719 = egs_4719.reset_index(drop=True)
egs_4719.loc[:, egs_4719.columns != 'Регион'] = egs_4719.loc[:, egs_4719.columns != 'Регион'].astype(int)
egs_4719.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1935426449.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4719['Регион'] = egs_4719['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1935426449.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4719.loc[:, egs_4719.columns != 'Регион'] = egs_4719.loc[:, egs_4719.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4819 = pd.read_excel('crimes/4-EGS_Razdel_4_082019.xls', header=9)
egs_4819 = egs_4819.drop('Unnamed: 0', axis=1)
egs_4819 = egs_4819.rename(columns=column_name)
egs_4819 = egs_4819.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4819 = egs_4819[~egs_4819['Регион'].isin(list_region)]
egs_4819['Регион'] = egs_4819['Регион'].str.replace(r"\(.*\)","")
egs_4819 = egs_4819.reset_index(drop=True)
egs_4819.loc[:, egs_4819.columns != 'Регион'] = egs_4819.loc[:, egs_4819.columns != 'Регион'].astype(int)
egs_4819.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\453483326.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4819['Регион'] = egs_4819['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\453483326.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4819.loc[:, egs_4819.columns != 'Регион'] = egs_4819.loc[:, egs_4819.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4919 = pd.read_excel('crimes/4-EGS_Razdel_4_092019.xls', header=9)
egs_4919 = egs_4919.drop('Unnamed: 0', axis=1)
egs_4919 = egs_4919.rename(columns=column_name)
egs_4919 = egs_4919.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4919 = egs_4919[~egs_4919['Регион'].isin(list_region)]
egs_4919['Регион'] = egs_4919['Регион'].str.replace(r"\(.*\)","")
egs_4919 = egs_4919.reset_index(drop=True)
egs_4919.loc[:, egs_4919.columns != 'Регион'] = egs_4919.loc[:, egs_4919.columns != 'Регион'].astype(int)
egs_4919.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1003815506.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4919['Регион'] = egs_4919['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1003815506.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4919.loc[:, egs_4919.columns != 'Регион'] = egs_4919.loc[:, egs_4919.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41019 = pd.read_excel('crimes/4-EGS_Razdel_4_102019.xls', header=9)
egs_41019 = egs_41019.drop('Unnamed: 0', axis=1)
egs_41019 = egs_41019.rename(columns=column_name)
egs_41019 = egs_41019.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41019 = egs_41019[~egs_41019['Регион'].isin(list_region)]
egs_41019['Регион'] = egs_41019['Регион'].str.replace(r"\(.*\)","")
egs_41019 = egs_41019.reset_index(drop=True)
egs_41019.loc[:, egs_41019.columns != 'Регион'] = egs_41019.loc[:, egs_41019.columns != 'Регион'].astype(int)
egs_41019.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3420776471.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41019['Регион'] = egs_41019['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3420776471.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41019.loc[:, egs_41019.columns != 'Регион'] = egs_41019.loc[:, egs_41019.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41119 = pd.read_excel('crimes/4-EGS_Razdel_4_112019.xls', header=9)
egs_41119 = egs_41119.drop('Unnamed: 0', axis=1)
egs_41119 = egs_41119.rename(columns=column_name)
egs_41119 = egs_41119.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41119 = egs_41119[~egs_41119['Регион'].isin(list_region)]
egs_41119['Регион'] = egs_41119['Регион'].str.replace(r"\(.*\)","")
egs_41119 = egs_41119.reset_index(drop=True)
egs_41119.loc[:, egs_41119.columns != 'Регион'] = egs_41119.loc[:, egs_41119.columns != 'Регион'].astype(int)
egs_41119.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2058596648.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41119['Регион'] = egs_41119['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2058596648.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41119.loc[:, egs_41119.columns != 'Регион'] = egs_41119.loc[:, egs_41119.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41219 = pd.read_excel('crimes/4-EGS_Razdel_4_122019.xls', header=9)
egs_41219 = egs_41219.drop('Unnamed: 0', axis=1)
egs_41219 = egs_41219.rename(columns=column_name)
egs_41219 = egs_41219.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41219 = egs_41219[~egs_41219['Регион'].isin(list_region)]
egs_41219['Регион'] = egs_41219['Регион'].str.replace(r"\(.*\)","")
egs_41219 = egs_41219.reset_index(drop=True)
egs_41219.loc[:, egs_41219.columns != 'Регион'] = egs_41219.loc[:, egs_41219.columns != 'Регион'].astype(int)
egs_41219.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4103490162.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41219['Регион'] = egs_41219['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4103490162.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41219.loc[:, egs_41219.columns != 'Регион'] = egs_41219.loc[:, egs_41219.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_419 = pd.concat([egs_4119, egs_4219, egs_4319, egs_4419, egs_4519, egs_4619, egs_4719, egs_4819, egs_4919,
                          egs_41019, egs_41119, egs_41219]).groupby('Регион').sum().reset_index()
column_name1 = {'Несовершеннолетними или при их соучастии': 'Несовершеннолетними или при их соучастии 2019',
               'Ранее совершавшими преступления': 'Ранее совершавшими преступления 2019','В том числе ранее судимыми': 'В том числе ранее судимыми 2019', 
               'Группой лиц': 'Группой лиц 2019', 'Группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2019',
               'Организованной группой': 'Организованной группой 2019', 'Преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2019',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2019', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2019',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2019'}

egs_419 = egs_419.rename(columns=column_name1)
egs_419.isna().sum().sum()
# Out:
# 0

# %%
egs_4120 = pd.read_excel('crimes/4-EGS_Razdel_4_012020.xls', header=9)
egs_4120 = egs_4120.drop('Unnamed: 0', axis=1)
egs_4120 = egs_4120.rename(columns=column_name)
egs_4120 = egs_4120.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4120 = egs_4120[~egs_4120['Регион'].isin(list_region)]
egs_4120['Регион'] = egs_4120['Регион'].str.replace(r"\(.*\)","")
egs_4120 = egs_4120.reset_index(drop=True)
egs_4120.loc[:, egs_4120.columns != 'Регион'] = egs_4120.loc[:, egs_4120.columns != 'Регион'].astype(int)
egs_4120.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1986600079.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4120['Регион'] = egs_4120['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1986600079.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4120.loc[:, egs_4120.columns != 'Регион'] = egs_4120.loc[:, egs_4120.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4220 = pd.read_excel('crimes/4-EGS_Razdel_4_022020.xls', header=9)
egs_4220 = egs_4220.drop('Unnamed: 0', axis=1)
egs_4220 = egs_4220.rename(columns=column_name)
egs_4220 = egs_4220.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4220 = egs_4220[~egs_4220['Регион'].isin(list_region)]
egs_4220['Регион'] = egs_4220['Регион'].str.replace(r"\(.*\)","")
egs_4220 = egs_4220.reset_index(drop=True)
egs_4220.loc[:, egs_4220.columns != 'Регион'] = egs_4220.loc[:, egs_4220.columns != 'Регион'].astype(int)
egs_4220.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4051251695.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4220['Регион'] = egs_4220['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4051251695.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4220.loc[:, egs_4220.columns != 'Регион'] = egs_4220.loc[:, egs_4220.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4320 = pd.read_excel('crimes/4-EGS_Razdel_4_032020.xls', header=9)
egs_4320 = egs_4320.drop('Unnamed: 0', axis=1)
egs_4320 = egs_4320.rename(columns=column_name)
egs_4320 = egs_4320.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4320 = egs_4320[~egs_4320['Регион'].isin(list_region)]
egs_4320['Регион'] = egs_4320['Регион'].str.replace(r"\(.*\)","")
egs_4320 = egs_4320.reset_index(drop=True)
egs_4320.loc[:, egs_4320.columns != 'Регион'] = egs_4320.loc[:, egs_4320.columns != 'Регион'].astype(int)
egs_4320.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1732788581.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4320['Регион'] = egs_4320['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1732788581.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4320.loc[:, egs_4320.columns != 'Регион'] = egs_4320.loc[:, egs_4320.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4420 = pd.read_excel('crimes/4-EGS_Razdel_4_042020.xls', header=9)
egs_4420 = egs_4420.drop('Unnamed: 0', axis=1)
egs_4420 = egs_4420.rename(columns=column_name)
egs_4420 = egs_4420.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4420 = egs_4420[~egs_4420['Регион'].isin(list_region)]
egs_4420['Регион'] = egs_4420['Регион'].str.replace(r"\(.*\)","")
egs_4420 = egs_4420.reset_index(drop=True)
egs_4420.loc[:, egs_4420.columns != 'Регион'] = egs_4420.loc[:, egs_4420.columns != 'Регион'].astype(int)
egs_4420.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3056639025.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4420['Регион'] = egs_4420['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3056639025.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4420.loc[:, egs_4420.columns != 'Регион'] = egs_4420.loc[:, egs_4420.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4520 = pd.read_excel('crimes/4-EGS_Razdel_4_052020.xls', header=9)
egs_4520 = egs_4520.drop('Unnamed: 0', axis=1)
egs_4520 = egs_4520.rename(columns=column_name)
egs_4520 = egs_4520.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4520 = egs_4520[~egs_4520['Регион'].isin(list_region)]
egs_4520['Регион'] = egs_4520['Регион'].str.replace(r"\(.*\)","")
egs_4520 = egs_4520.reset_index(drop=True)
egs_4520.loc[:, egs_4520.columns != 'Регион'] = egs_4520.loc[:, egs_4520.columns != 'Регион'].astype(int)
egs_4520.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2491209209.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4520['Регион'] = egs_4520['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2491209209.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4520.loc[:, egs_4520.columns != 'Регион'] = egs_4520.loc[:, egs_4520.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4620 = pd.read_excel('crimes/4-EGS_Razdel_4_062020.xls', header=9)
egs_4620 = egs_4620.drop('Unnamed: 0', axis=1)
egs_4620 = egs_4620.rename(columns=column_name)
egs_4620 = egs_4620.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4620 = egs_4620[~egs_4620['Регион'].isin(list_region)]
egs_4620['Регион'] = egs_4620['Регион'].str.replace(r"\(.*\)","")
egs_4620 = egs_4620.reset_index(drop=True)
egs_4620.loc[:, egs_4620.columns != 'Регион'] = egs_4620.loc[:, egs_4620.columns != 'Регион'].astype(int)
egs_4620.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3668312051.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4620['Регион'] = egs_4620['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3668312051.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4620.loc[:, egs_4620.columns != 'Регион'] = egs_4620.loc[:, egs_4620.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4720 = pd.read_excel('crimes/4-EGS_Razdel_4_072020.xls', header=9)
egs_4720 = egs_4720.drop('Unnamed: 0', axis=1)
egs_4720 = egs_4720.rename(columns=column_name)
egs_4720 = egs_4720.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4720 = egs_4720[~egs_4720['Регион'].isin(list_region)]
egs_4720['Регион'] = egs_4720['Регион'].str.replace(r"\(.*\)","")
egs_4720 = egs_4720.reset_index(drop=True)
egs_4720.loc[:, egs_4720.columns != 'Регион'] = egs_4720.loc[:, egs_4720.columns != 'Регион'].astype(int)
egs_4720.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1584467367.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4720['Регион'] = egs_4720['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1584467367.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4720.loc[:, egs_4720.columns != 'Регион'] = egs_4720.loc[:, egs_4720.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4820 = pd.read_excel('crimes/4-EGS_Razdel_4_082020.xls', header=9)
egs_4820 = egs_4820.drop('Unnamed: 0', axis=1)
egs_4820 = egs_4820.rename(columns=column_name)
egs_4820 = egs_4820.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4820 = egs_4820[~egs_4820['Регион'].isin(list_region)]
egs_4820['Регион'] = egs_4820['Регион'].str.replace(r"\(.*\)","")
egs_4820 = egs_4820.reset_index(drop=True)
egs_4820.loc[:, egs_4820.columns != 'Регион'] = egs_4820.loc[:, egs_4820.columns != 'Регион'].astype(int)
egs_4820.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4287014596.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4820['Регион'] = egs_4820['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4287014596.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4820.loc[:, egs_4820.columns != 'Регион'] = egs_4820.loc[:, egs_4820.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4920 = pd.read_excel('crimes/4-EGS_Razdel_4_092020.xls', header=9)
egs_4920 = egs_4920.drop('Unnamed: 0', axis=1)
egs_4920 = egs_4920.rename(columns=column_name)
egs_4920 = egs_4920.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4920 = egs_4920[~egs_4920['Регион'].isin(list_region)]
egs_4920['Регион'] = egs_4920['Регион'].str.replace(r"\(.*\)","")
egs_4920 = egs_4920.reset_index(drop=True)
egs_4920.loc[:, egs_4920.columns != 'Регион'] = egs_4920.loc[:, egs_4920.columns != 'Регион'].astype(int)
egs_4920.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\49955433.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4920['Регион'] = egs_4920['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\49955433.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4920.loc[:, egs_4920.columns != 'Регион'] = egs_4920.loc[:, egs_4920.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41020 = pd.read_excel('crimes/4-EGS_Razdel_4_102020.xls', header=9)
egs_41020 = egs_41020.drop('Unnamed: 0', axis=1)
egs_41020 = egs_41020.rename(columns=column_name)
egs_41020 = egs_41020.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41020 = egs_41020[~egs_41020['Регион'].isin(list_region)]
egs_41020['Регион'] = egs_41020['Регион'].str.replace(r"\(.*\)","")
egs_41020 = egs_41020.reset_index(drop=True)
egs_41020.loc[:, egs_41020.columns != 'Регион'] = egs_41020.loc[:, egs_41020.columns != 'Регион'].astype(int)
egs_41020.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2624274921.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41020['Регион'] = egs_41020['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2624274921.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41020.loc[:, egs_41020.columns != 'Регион'] = egs_41020.loc[:, egs_41020.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41120 = pd.read_excel('crimes/4-EGS_Razdel_4_112020.xls', header=9)
egs_41120 = egs_41120.drop('Unnamed: 0', axis=1)
egs_41120 = egs_41120.rename(columns=column_name)
egs_41120 = egs_41120.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41120 = egs_41120[~egs_41120['Регион'].isin(list_region)]
egs_41120['Регион'] = egs_41120['Регион'].str.replace(r"\(.*\)","")
egs_41120 = egs_41120.reset_index(drop=True)
egs_41120.loc[:, egs_41120.columns != 'Регион'] = egs_41120.loc[:, egs_41120.columns != 'Регион'].astype(int)
egs_41120.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1298748640.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41120['Регион'] = egs_41120['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1298748640.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41120.loc[:, egs_41120.columns != 'Регион'] = egs_41120.loc[:, egs_41120.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41220 = pd.read_excel('crimes/4-EGS_Razdel_4_122020.xls', header=9)
egs_41220 = egs_41220.drop('Unnamed: 0', axis=1)
egs_41220 = egs_41220.rename(columns=column_name)
egs_41220 = egs_41220.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41220 = egs_41220[~egs_41220['Регион'].isin(list_region)]
egs_41220['Регион'] = egs_41220['Регион'].str.replace(r"\(.*\)","")
egs_41220 = egs_41220.reset_index(drop=True)
egs_41220.loc[:, egs_41220.columns != 'Регион'] = egs_41220.loc[:, egs_41220.columns != 'Регион'].astype(int)
egs_41220.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1072282493.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41220['Регион'] = egs_41220['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1072282493.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41220.loc[:, egs_41220.columns != 'Регион'] = egs_41220.loc[:, egs_41220.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_420 = pd.concat([egs_4120, egs_4220, egs_4320, egs_4420, egs_4520, egs_4620, egs_4720, egs_4820, egs_4920,
                          egs_41020, egs_41120, egs_41220]).groupby('Регион').sum().reset_index()
column_name1 = {'Несовершеннолетними или при их соучастии':'Несовершеннолетними или при их соучастии 2020',
               'Ранее совершавшими преступления':'Ранее совершавшими преступления 2020','В том числе ранее судимыми': 'В том числе ранее судимыми 2020', 
               'Группой лиц': 'Группой лиц 2020', 'Группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2020',
               'Организованной группой': 'Организованной группой 2020', 'Преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2020',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2020', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2020',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2020'}
egs_420 = egs_420.rename(columns=column_name1)

egs_420.isna().sum().sum()
# Out:
# 0

# %%
egs_4121 = pd.read_excel('crimes/4-EGS_Razdel_5_012021.xls', header=9)
egs_4121 = egs_4121.drop('Unnamed: 0', axis=1)
egs_4121 = egs_4121.rename(columns=column_name)
new_column_name = {'членом семьи, супругом, сожителем, сексуальным партнером (в том числе бывшими)': 'Членом семьи, супругом, сожителем, сексуальным партнером (в том числе бывшими)',
                   'из них в отношении': 'Из них в отношении женщин', 'Unnamed: 14': 'Из них в отношении несовершеннолетних',
                   'иностранными гражданами и лицами без гражданства': 'Иностранными гражданами и лицами без гражданства',
                   'из них': 'Из них гражданами государств – участников СНГ', 'Unnamed: 17': 'Из них трудовых мигрантов', 'Unnamed: 18': 'Из них незаконных мигрантов'}
egs_4121 = egs_4121.rename(columns=new_column_name)
egs_4121 = egs_4121.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4121 = egs_4121[~egs_4121['Регион'].isin(list_region)]
egs_4121['Регион'] = egs_4121['Регион'].str.replace(r"\(.*\)","")
egs_4121 = egs_4121.reset_index(drop=True)
egs_4121.loc[:, egs_4121.columns != 'Регион'] = egs_4121.loc[:, egs_4121.columns != 'Регион'].astype(int)
egs_4121.Регион.unique()
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2361958142.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4121['Регион'] = egs_4121['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2361958142.py:13: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4121.loc[:, egs_4121.columns != 'Регион'] = egs_4121.loc[:, egs_4121.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
#        'Московская область', 'Липецкая область', 'Орловская область',
# ...

# %%
egs_4121
# Out:
#                         Регион  несовершеннолетними или при их соучастии  \
# 0         Белгородская область                                         5
# 1             Брянская область                                         8
# 2         Владимирская область                                        20
# 3          Воронежская область                                        42
# 4           Ивановская область                                        17
# ..                         ...                                       ...
# 80          Республика Бурятия                                        46
# 81            Республика Саха                                         20
# 82         Сахалинская область                                        16
# 83            Хабаровский край                                        54
# 84  Чукотский автономный округ                                         0
#
#     ранее совершавшими преступления  В том числе ранее судимыми  группой лиц  \
# ...

# %%
egs_4221 = pd.read_excel('crimes/4-EGS_Razdel_5_022021.xls', header=9)
egs_4221 = egs_4221.drop('Unnamed: 0', axis=1)
egs_4221 = egs_4221.rename(columns=column_name)
egs_4221 = egs_4221.rename(columns=new_column_name)
egs_4221 = egs_4221.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4221 = egs_4221[~egs_4221['Регион'].isin(list_region)]
egs_4221['Регион'] = egs_4221['Регион'].str.replace(r"\(.*\)","")
egs_4221 = egs_4221.reset_index(drop=True)
egs_4221.loc[:, egs_4221.columns != 'Регион'] = egs_4221.loc[:, egs_4221.columns != 'Регион'].astype(int)
egs_4221.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2734108992.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4221['Регион'] = egs_4221['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2734108992.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4221.loc[:, egs_4221.columns != 'Регион'] = egs_4221.loc[:, egs_4221.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4321 = pd.read_excel('crimes/4-EGS_Razdel_5_032021.xls', header=9)
egs_4321 = egs_4321.drop('Unnamed: 0', axis=1)
egs_4321 = egs_4321.rename(columns=column_name)
egs_4321 = egs_4321.rename(columns=new_column_name)
egs_4321 = egs_4321.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4321 = egs_4321[~egs_4321['Регион'].isin(list_region)]
egs_4321['Регион'] = egs_4321['Регион'].str.replace(r"\(.*\)","")
egs_4321 = egs_4321.reset_index(drop=True)
egs_4321.loc[:, egs_4321.columns != 'Регион'] = egs_4321.loc[:, egs_4321.columns != 'Регион'].astype(int)
egs_4321.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2750667534.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4321['Регион'] = egs_4321['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\2750667534.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4321.loc[:, egs_4321.columns != 'Регион'] = egs_4321.loc[:, egs_4321.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4421 = pd.read_excel('crimes/4-EGS_Razdel_5_042021.xls', header=9)
egs_4421 = egs_4421.drop('Unnamed: 0', axis=1)
egs_4421 = egs_4421.rename(columns=column_name)
egs_4421 = egs_4421.rename(columns=new_column_name)
egs_4421 = egs_4421.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4421 = egs_4421[~egs_4421['Регион'].isin(list_region)]
egs_4421['Регион'] = egs_4421['Регион'].str.replace(r"\(.*\)","")
egs_4421 = egs_4421.reset_index(drop=True)
egs_4421.loc[:, egs_4421.columns != 'Регион'] = egs_4421.loc[:, egs_4421.columns != 'Регион'].astype(int)
egs_4421.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1631200175.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4421['Регион'] = egs_4421['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\1631200175.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4421.loc[:, egs_4421.columns != 'Регион'] = egs_4421.loc[:, egs_4421.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4521 = pd.read_excel('crimes/4-EGS_Razdel_5_052021.xls', header=9)
egs_4521 = egs_4521.drop('Unnamed: 0', axis=1)
egs_4521 = egs_4521.rename(columns=column_name)
egs_4521 = egs_4521.rename(columns=new_column_name)
egs_4521 = egs_4521.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4521 = egs_4521[~egs_4521['Регион'].isin(list_region)]
egs_4521['Регион'] = egs_4521['Регион'].str.replace(r"\(.*\)","")
egs_4521 = egs_4521.reset_index(drop=True)
egs_4521.loc[:, egs_4521.columns != 'Регион'] = egs_4521.loc[:, egs_4521.columns != 'Регион'].astype(int)
egs_4521.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4112638988.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4521['Регион'] = egs_4521['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\4112638988.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4521.loc[:, egs_4521.columns != 'Регион'] = egs_4521.loc[:, egs_4521.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4621 = pd.read_excel('crimes/4-EGS_Razdel_5_062021.xls', header=9)
egs_4621 = egs_4621.drop('Unnamed: 0', axis=1)
egs_4621 = egs_4621.rename(columns=column_name)
egs_4621 = egs_4621.rename(columns=new_column_name)
egs_4621 = egs_4621.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4621 = egs_4621[~egs_4621['Регион'].isin(list_region)]
egs_4621['Регион'] = egs_4621['Регион'].str.replace(r"\(.*\)","")
egs_4621 = egs_4621.reset_index(drop=True)
egs_4621.loc[:, egs_4621.columns != 'Регион'] = egs_4621.loc[:, egs_4621.columns != 'Регион'].astype(int)
egs_4621.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3253401254.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4621['Регион'] = egs_4621['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3253401254.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4621.loc[:, egs_4621.columns != 'Регион'] = egs_4621.loc[:, egs_4621.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4721 = pd.read_excel('crimes/4-EGS_Razdel_5_072021.xls', header=9)
egs_4721 = egs_4721.drop('Unnamed: 0', axis=1)
egs_4721 = egs_4721.rename(columns=column_name)
egs_4721 = egs_4721.rename(columns=new_column_name)
egs_4721 = egs_4721.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4721 = egs_4721[~egs_4721['Регион'].isin(list_region)]
egs_4721['Регион'] = egs_4721['Регион'].str.replace(r"\(.*\)","")
egs_4721 = egs_4721.reset_index(drop=True)
egs_4721.loc[:, egs_4721.columns != 'Регион'] = egs_4721.loc[:, egs_4721.columns != 'Регион'].astype(int)
egs_4721.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\297708444.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4721['Регион'] = egs_4721['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\297708444.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4721.loc[:, egs_4721.columns != 'Регион'] = egs_4721.loc[:, egs_4721.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4821 = pd.read_excel('crimes/4-EGS_Razdel_5_082021.xls', header=9)
egs_4821 = egs_4821.drop('Unnamed: 0', axis=1)
egs_4821 = egs_4821.rename(columns=column_name)
egs_4821 = egs_4821.rename(columns=new_column_name)
egs_4821 = egs_4821.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4821 = egs_4821[~egs_4821['Регион'].isin(list_region)]
egs_4821['Регион'] = egs_4821['Регион'].str.replace(r"\(.*\)","")
egs_4821 = egs_4821.reset_index(drop=True)
egs_4821.loc[:, egs_4821.columns != 'Регион'] = egs_4821.loc[:, egs_4821.columns != 'Регион'].astype(int)
egs_4821.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\845421267.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4821['Регион'] = egs_4821['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\845421267.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4821.loc[:, egs_4821.columns != 'Регион'] = egs_4821.loc[:, egs_4821.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_4921 = pd.read_excel('crimes/4-EGS_Razdel_5_092021.xls', header=9)
egs_4921 = egs_4921.drop('Unnamed: 0', axis=1)
egs_4921 = egs_4921.rename(columns=column_name)
egs_4921 = egs_4921.rename(columns=new_column_name)
egs_4921 = egs_4921.drop(index=[ 0, 1]).reset_index(drop=True)
egs_4921 = egs_4921[~egs_4921['Регион'].isin(list_region)]
egs_4921['Регион'] = egs_4921['Регион'].str.replace(r"\(.*\)","")
egs_4921 = egs_4921.reset_index(drop=True)
egs_4921.loc[:, egs_4921.columns != 'Регион'] = egs_4921.loc[:, egs_4921.columns != 'Регион'].astype(int)
egs_4921.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3442755147.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_4921['Регион'] = egs_4921['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3442755147.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4921.loc[:, egs_4921.columns != 'Регион'] = egs_4921.loc[:, egs_4921.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41021 = pd.read_excel('crimes/4-EGS_Razdel_5_102021.xls', header=9)
egs_41021 = egs_41021.drop('Unnamed: 0', axis=1)
egs_41021 = egs_41021.rename(columns=column_name)
egs_41021 = egs_41021.rename(columns=new_column_name)
egs_41021 = egs_41021.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41021 = egs_41021[~egs_41021['Регион'].isin(list_region)]
egs_41021['Регион'] = egs_41021['Регион'].str.replace(r"\(.*\)","")
egs_41021 = egs_41021.reset_index(drop=True)
egs_41021.loc[:, egs_41021.columns != 'Регион'] = egs_41021.loc[:, egs_41021.columns != 'Регион'].astype(int)
egs_41021.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\379590798.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41021['Регион'] = egs_41021['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\379590798.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41021.loc[:, egs_41021.columns != 'Регион'] = egs_41021.loc[:, egs_41021.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41121 = pd.read_excel('crimes/4-EGS_Razdel_5_112021.xls', header=9)
egs_41121 = egs_41121.drop('Unnamed: 0', axis=1)
egs_41121 = egs_41121.rename(columns=column_name)
egs_41121 = egs_41121.rename(columns=new_column_name)
egs_41121 = egs_41121.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41121 = egs_41121[~egs_41121['Регион'].isin(list_region)]
egs_41121['Регион'] = egs_41121['Регион'].str.replace(r"\(.*\)","")
egs_41121 = egs_41121.reset_index(drop=True)
egs_41121.loc[:, egs_41121.columns != 'Регион'] = egs_41121.loc[:, egs_41121.columns != 'Регион'].astype(int)
egs_41121.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3644965587.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41121['Регион'] = egs_41121['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3644965587.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41121.loc[:, egs_41121.columns != 'Регион'] = egs_41121.loc[:, egs_41121.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_41221 = pd.read_excel('crimes/4-EGS_Razdel_5_122021.xls', header=9)
egs_41221 = egs_41221.drop('Unnamed: 0', axis=1)
egs_41221 = egs_41221.rename(columns=column_name)
egs_41221 = egs_41221.rename(columns=new_column_name)
egs_41221 = egs_41221.drop(index=[ 0, 1]).reset_index(drop=True)
egs_41221 = egs_41221[~egs_41221['Регион'].isin(list_region)]
egs_41221['Регион'] = egs_41221['Регион'].str.replace(r"\(.*\)","")
egs_41221 = egs_41221.reset_index(drop=True)
egs_41221.loc[:, egs_41221.columns != 'Регион'] = egs_41221.loc[:, egs_41221.columns != 'Регион'].astype(int)
egs_41221.Регион.unique()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3218616279.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   egs_41221['Регион'] = egs_41221['Регион'].str.replace(r"\(.*\)","")
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\3218616279.py:9: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_41221.loc[:, egs_41221.columns != 'Регион'] = egs_41221.loc[:, egs_41221.columns != 'Регион'].astype(int)
# array(['Белгородская область', 'Брянская область', 'Владимирская область',
#        'Воронежская область', 'Ивановская область', 'Калужская область',
#        'Костромская область', 'Курская область', 'г. Москва',
# ...

# %%
egs_421 = pd.concat([egs_4121, egs_4221, egs_4321, egs_4421, egs_4521, egs_4621, egs_4721, egs_4821, egs_4921,
                          egs_41021, egs_41121, egs_41221]).groupby('Регион').sum().reset_index()
column_name1 = {'несовершеннолетними или при их соучастии':'Несовершеннолетними или при их соучастии 2021',
               'ранее совершавшими преступления':'Ранее совершавшими преступления 2021','В том числе ранее судимыми': 'В том числе ранее судимыми 2021', 
               'группой лиц': 'Группой лиц 2021', 'группой лиц по предварительному сговору': 'Группой лиц по предварительному сговору 2021',
               'организованной группой': 'Организованной группой 2021', 'преступным сообществом (преступной организацией)': 'Преступным сообществом (преступной организацией) 2021',
               'В состоянии алкогольного опьянения': 'В состоянии алкогольного опьянения 2021', 'В состоянии наркотического опьянения': 'В состоянии наркотического опьянения 2021',
               'В состоянии токсического опьянения': 'В состоянии токсического опьянения 2021', 
               'Членом семьи, супругом, сожителем, сексуальным партнером (в том числе бывшими)': 'Членом семьи, супругом, сожителем, сексуальным партнером (в том числе бывшими) 2021',
               'Из них в отношении женщин': 'Из них в отношении женщин 2021', 'Из них в отношении несовершеннолетних': 'Из них в отношении несовершеннолетних 2021',
               'Иностранными гражданами и лицами без гражданства': 'Иностранными гражданами и лицами без гражданства 2021',
               'Из них гражданами государств – участников СНГ': 'Из них гражданами государств – участников СНГ 2021',
               'Из них трудовых мигрантов': 'Из них трудовых мигрантов 2021', 'Из них незаконных мигрантов': 'Из них незаконных мигрантов 2021'}


egs_421 = egs_421.rename(columns=column_name1)
egs_421.isna().sum().sum()
# Out:
# 0

# %%
egs_421.Регион.unique()
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область',
#        'Еврейская автономная область', 'Забайкальский край',
#        'Ивановская область', 'Иркутская область',
#        'Кабардино-Балкарская Республика', 'Калининградская область',
#        'Калужская область', 'Камчатский край',
#        'Карачаево-Черкесская Республика', 'Кемеровская область – Кузбасс',
#        'Кировская область', 'Костромская область', 'Краснодарский край',
#        'Красноярский край', 'Курганская область', 'Курская область',
#        'Ленинградская область', 'Липецкая область', 'Магаданская область',
#        'Московская область', 'Мурманская область',
#        'Ненецкий автономный округ', 'Нижегородская область',
#        'Новгородская  область', 'Новосибирская область', 'Омская область',
# ...

# %%
egs_41 = pd.concat([egs_416, egs_417, egs_418]).groupby('Регион').sum().reset_index()

egs_41
# Out:
#                              Регион  \
# 0                    Алтайский край
# 1                  Амурская область
# 2             Архангельская область
# 3              Астраханская область
# 4              Белгородская область
# ..                              ...
# 80  Ямало-Ненецкий автономный округ
# 81              Ярославская область
# 82                        г. Москва
# 83               г. Санкт-Петербург
# 84                   г. Севастополь
#
#     Несовершеннолетними или при их соучастии 2016  \
# 0                                          8406.0
# 1                                          4758.0
# 2                                          4589.0
# 3                                          2445.0
# 4                                          1712.0
# ..                                            ...
# 80                                         1580.0
# 81                                         3106.0
# 82                                         4931.0
# ...

# %%
egs_42 = pd.concat([egs_419, egs_420, egs_421]).groupby('Регион').sum().reset_index()
dict_name1 = {'Ханты-Мансийский автономный округ –  Югра': 'Ханты-Мансийский автономный округ - Югра', 'Республика Северная Осетия-Алания': 'Республика Северная Осетия – Алания',
              'Кемеровская область': 'Кемеровская область – Кузбасс'}
egs_42.Регион = egs_42.Регион.replace(dict_name1, regex=True)
egs_42.Регион = egs_42.Регион.replace('Кемеровская область – Кузбасс – Кузбасс', 'Кемеровская область – Кузбасс', regex=True)
egs_42.Регион.unique()
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область',
#        'Еврейская автономная область', 'Забайкальский край',
#        'Ивановская область', 'Иркутская область',
#        'Кабардино-Балкарская Республика', 'Калининградская область',
#        'Калужская область', 'Камчатский край',
#        'Карачаево-Черкесская Республика', 'Кемеровская область – Кузбасс',
#        'Кировская область', 'Костромская область', 'Краснодарский край',
#        'Красноярский край', 'Курганская область', 'Курская область',
#        'Ленинградская область', 'Липецкая область', 'Магаданская область',
#        'Московская область', 'Мурманская область',
#        'Ненецкий автономный округ', 'Нижегородская область',
#        'Новгородская  область', 'Новосибирская область', 'Омская область',
# ...

# %%
egs_4 = pd.concat([egs_41, egs_42]).groupby('Регион').sum().reset_index()
egs_4.Регион = egs_4.Регион.str.strip()
egs_4.loc[:, egs_4.columns != 'Регион'] = egs_4.loc[:, egs_4.columns != 'Регион'].astype(int)
egs_4
# Out:
# C:\Users\Алексей\AppData\Local\Temp\ipykernel_11880\92546241.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   egs_4.loc[:, egs_4.columns != 'Регион'] = egs_4.loc[:, egs_4.columns != 'Регион'].astype(int)
#                              Регион  \
# 0                    Алтайский край
# 1                  Амурская область
# 2             Архангельская область
# 3              Астраханская область
# 4              Белгородская область
# ..                              ...
# 80  Ямало-Ненецкий автономный округ
# 81              Ярославская область
# 82                        г. Москва
# 83               г. Санкт-Петербург
# 84                   г. Севастополь
#
#     Несовершеннолетними или при их соучастии 2016  \
# ...

# %%
egs_4.Регион.unique()
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область',
#        'Еврейская автономная область', 'Забайкальский край',
#        'Ивановская область', 'Иркутская область',
#        'Кабардино-Балкарская Республика', 'Калининградская область',
#        'Калужская область', 'Камчатский край',
#        'Карачаево-Черкесская Республика', 'Кемеровская область – Кузбасс',
#        'Кировская область', 'Костромская область', 'Краснодарский край',
#        'Красноярский край', 'Курганская область', 'Курская область',
#        'Ленинградская область', 'Липецкая область', 'Магаданская область',
#        'Московская область', 'Мурманская область',
#        'Ненецкий автономный округ', 'Нижегородская область',
#        'Новгородская  область', 'Новосибирская область', 'Омская область',
# ...

# %%
egs_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 68 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Регион                                                                               85 non-null     object
#  1   Несовершеннолетними или при их соучастии 2016                                        85 non-null     int32
#  2   Ранее совершавшими преступления 2016                                                 85 non-null     int32
#  3   В том числе ранее судимыми 2016                                                      85 non-null     int32
#  4   Группой лиц 2016                                                                     85 non-null     int32
# ...

# %%
filename = 'data_crimes.csv'
egs_4.to_csv(filename, index=False)

print(f"CSV file '{filename}' created successfully.")
# Out:
# CSV file 'data_crimes.csv' created successfully.
